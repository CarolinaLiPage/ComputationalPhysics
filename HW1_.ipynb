# %%
import math 

# physical constants
m = 9.11*10**(-31) #kg
E = 10 #eV
V = 9 #ev
h_bar = 1.054571817*10**(-34) #Js

# Exercise 1: Quantum Potential Step
if E > V: #Only when E>V, the particle may have two cases
  k_1 = (math.sqrt(2*m*E))/h_bar
  k_2 = (math.sqrt(2*m*(E-V)))/h_bar
  # case (a): pass the step
  T = (4*k_1*k_2)/(k_1+k_2)**2
  print("The probabilities T for transmission: ")
  print(T)

  #case (b): reflected
  R = ((k_1-k_2)/(k_1+k_2))**2
  print("The probabilities R for reflection: ")
  print(R)

print("===============================================================================================")

# Exercise 2: Lorenz
x = []
y = []
z = []
roh = 10
b = 8/3
r = 28
dt = 0.01
x0 = 1
y0 = 2
z0 = 3
x.append(x0)
y.append(y0)
z.append(z0)
print("computer the first 1000 elements of the sequences:")
# computer the first 1000 elements of the sequences
for i in range(0,999):
  x_next = x[i] + roh*(y[i]-x[i])*dt
  y_next = y[i] + (x[i]*(r-z[i])-y[i])*dt
  z_next = z[i] + (x[i]*y[i]-b*z[i])*dt
  x.append(x_next)
  y.append(y_next)
  z.append(z_next)

print(x)
print(y)
print(z)

#Plot the trajectory in 3D
print("Plot the trajectory in 3D")
import matplotlib.pyplot as plt

fig = plt.figure()
ax = fig.gca(projection='3d')
ax.plot(x,y,z)
plt.show()

print("===============================================================================================")

# ##  Extras:
print("Extras:")
# # with different starting conditions
print("with different starting conditions:")
# case 1: 
x0 = 3
y0 = 2
z0 = 1
x[0] = x0
y[0] = y0
z[0] = z0
# computer the first 1000 elements of the sequences
for i in range(0,999):
  x_next = x[i] + roh*(y[i]-x[i])*dt
  y_next = y[i] + (x[i]*(r-z[i])-y[i])*dt
  z_next = z[i] + (x[i]*y[i]-b*z[i])*dt
  x[i+1] = x_next
  y[i+1] = y_next
  z[i+1] = z_next
#Plot the trajectory in 3D
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.gca(projection='3d')
ax.plot(x,y,z)
plt.show()

# case 2: 
x0 = -1
y0 = 0
z0 = 1
x[0] = x0
y[0] = y0
z[0] = z0
# computer the first 1000 elements of the sequences
for i in range(0,999):
  x_next = x[i] + roh*(y[i]-x[i])*dt
  y_next = y[i] + (x[i]*(r-z[i])-y[i])*dt
  z_next = z[i] + (x[i]*y[i]-b*z[i])*dt
  x[i+1] = x_next
  y[i+1] = y_next
  z[i+1] = z_next
#Plot the trajectory in 3D
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.gca(projection='3d')
ax.plot(x,y,z)
plt.show()

# case 3: 
x0 = -2
y0 = 0
z0 = 2
x[0] = x0
y[0] = y0
z[0] = z0
# computer the first 1000 elements of the sequences
for i in range(0,999):
  x_next = x[i] + roh*(y[i]-x[i])*dt
  y_next = y[i] + (x[i]*(r-z[i])-y[i])*dt
  z_next = z[i] + (x[i]*y[i]-b*z[i])*dt
  x[i+1] = x_next
  y[i+1] = y_next
  z[i+1] = z_next
#Plot the trajectory in 3D
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.gca(projection='3d')
ax.plot(x,y,z)
plt.show()

# case 4: 
x0 = 3
y0 = 5
z0 = 8
x[0] = x0
y[0] = y0
z[0] = z0
# computer the first 1000 elements of the sequences
for i in range(0,999):
  x_next = x[i] + roh*(y[i]-x[i])*dt
  y_next = y[i] + (x[i]*(r-z[i])-y[i])*dt
  z_next = z[i] + (x[i]*y[i]-b*z[i])*dt
  x[i+1] = x_next
  y[i+1] = y_next
  z[i+1] = z_next
#Plot the trajectory in 3D
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.gca(projection='3d')
ax.plot(x,y,z)
plt.show()

print("Conclusions: According to the above different starting conditions, we can find that it will affect the density and size of the two circles in the plot, left side circle and right side circle")
## Conclusions: According to the above different starting conditions, we can find that it will affect the density 
## and size of the two circles in the plot, left side circle and right side circle
print("===============================================================================================")

# with different values for roh, b and r
print("with different values for roh, b and r: ")
print("How does roh value affect the system?")
# case 1: 
roh = 2
b = 8/3
r = 28
x0 = 1
y0 = 2
z0 = 3
x[0] = x0
y[0] = y0
z[0] = z0
# computer the first 1000 elements of the sequences
for i in range(0,999):
  x_next = x[i] + roh*(y[i]-x[i])*dt
  y_next = y[i] + (x[i]*(r-z[i])-y[i])*dt
  z_next = z[i] + (x[i]*y[i]-b*z[i])*dt
  x[i+1] = x_next
  y[i+1] = y_next
  z[i+1] = z_next
#Plot the trajectory in 3D
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.gca(projection='3d')
ax.plot(x,y,z)
plt.show()

# case 2: 
roh = 5
b = 8/3
r = 28
x0 = 1
y0 = 2
z0 = 3
x[0] = x0
y[0] = y0
z[0] = z0
# computer the first 1000 elements of the sequences
for i in range(0,999):
  x_next = x[i] + roh*(y[i]-x[i])*dt
  y_next = y[i] + (x[i]*(r-z[i])-y[i])*dt
  z_next = z[i] + (x[i]*y[i]-b*z[i])*dt
  x[i+1] = x_next
  y[i+1] = y_next
  z[i+1] = z_next
#Plot the trajectory in 3D
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.gca(projection='3d')
ax.plot(x,y,z)
plt.show()

# case 3: 
roh = 8
b = 8/3
r = 28
x0 = 1
y0 = 2
z0 = 3
x[0] = x0
y[0] = y0
z[0] = z0
# computer the first 1000 elements of the sequences
for i in range(0,999):
  x_next = x[i] + roh*(y[i]-x[i])*dt
  y_next = y[i] + (x[i]*(r-z[i])-y[i])*dt
  z_next = z[i] + (x[i]*y[i]-b*z[i])*dt
  x[i+1] = x_next
  y[i+1] = y_next
  z[i+1] = z_next
#Plot the trajectory in 3D
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.gca(projection='3d')
ax.plot(x,y,z)
plt.show()

# case 4: 
roh = 15
b = 8/3
r = 28
x0 = 1
y0 = 2
z0 = 3
x[0] = x0
y[0] = y0
z[0] = z0
# computer the first 1000 elements of the sequences
for i in range(0,999):
  x_next = x[i] + roh*(y[i]-x[i])*dt
  y_next = y[i] + (x[i]*(r-z[i])-y[i])*dt
  z_next = z[i] + (x[i]*y[i]-b*z[i])*dt
  x[i+1] = x_next
  y[i+1] = y_next
  z[i+1] = z_next
#Plot the trajectory in 3D
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.gca(projection='3d')
ax.plot(x,y,z)
plt.show()

# case 5: 
roh = 20
b = 8/3
r = 28
x0 = 1
y0 = 2
z0 = 3
x[0] = x0
y[0] = y0
z[0] = z0
# computer the first 1000 elements of the sequences
for i in range(0,999):
  x_next = x[i] + roh*(y[i]-x[i])*dt
  y_next = y[i] + (x[i]*(r-z[i])-y[i])*dt
  z_next = z[i] + (x[i]*y[i]-b*z[i])*dt
  x[i+1] = x_next
  y[i+1] = y_next
  z[i+1] = z_next
#Plot the trajectory in 3D
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.gca(projection='3d')
ax.plot(x,y,z)
plt.show()

# Conclusions: Roh value affects the numbers of the circles both in the left side and right side
print("Conclusions: Roh value affects the numbers of the circles both in the left side and right side")
print("===============================================================================================")

print("How does b value affect the system?")

# case 1: 
roh = 10
b = 1
r = 28
x0 = 1
y0 = 2
z0 = 3
x[0] = x0
y[0] = y0
z[0] = z0
# computer the first 1000 elements of the sequences
for i in range(0,999):
  x_next = x[i] + roh*(y[i]-x[i])*dt
  y_next = y[i] + (x[i]*(r-z[i])-y[i])*dt
  z_next = z[i] + (x[i]*y[i]-b*z[i])*dt
  x[i+1] = x_next
  y[i+1] = y_next
  z[i+1] = z_next
#Plot the trajectory in 3D
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.gca(projection='3d')
ax.plot(x,y,z)
plt.show()

# case 2: 
roh = 10
b = 5
r = 28
x0 = 1
y0 = 2
z0 = 3
x[0] = x0
y[0] = y0
z[0] = z0
# computer the first 1000 elements of the sequences
for i in range(0,999):
  x_next = x[i] + roh*(y[i]-x[i])*dt
  y_next = y[i] + (x[i]*(r-z[i])-y[i])*dt
  z_next = z[i] + (x[i]*y[i]-b*z[i])*dt
  x[i+1] = x_next
  y[i+1] = y_next
  z[i+1] = z_next
#Plot the trajectory in 3D
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.gca(projection='3d')
ax.plot(x,y,z)
plt.show()

# case 3: 
roh = 10
b = 8
r = 28
x0 = 1
y0 = 2
z0 = 3
x[0] = x0
y[0] = y0
z[0] = z0
# computer the first 1000 elements of the sequences
for i in range(0,999):
  x_next = x[i] + roh*(y[i]-x[i])*dt
  y_next = y[i] + (x[i]*(r-z[i])-y[i])*dt
  z_next = z[i] + (x[i]*y[i]-b*z[i])*dt
  x[i+1] = x_next
  y[i+1] = y_next
  z[i+1] = z_next
#Plot the trajectory in 3D
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.gca(projection='3d')
ax.plot(x,y,z)
plt.show()

# case 4: 
roh = 10
b = 12
r = 28
x0 = 1
y0 = 2
z0 = 3
x[0] = x0
y[0] = y0
z[0] = z0
# computer the first 1000 elements of the sequences
for i in range(0,999):
  x_next = x[i] + roh*(y[i]-x[i])*dt
  y_next = y[i] + (x[i]*(r-z[i])-y[i])*dt
  z_next = z[i] + (x[i]*y[i]-b*z[i])*dt
  x[i+1] = x_next
  y[i+1] = y_next
  z[i+1] = z_next
#Plot the trajectory in 3D
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.gca(projection='3d')
ax.plot(x,y,z)
plt.show()

# case 5: 
roh = 10
b = 15
r = 28
x0 = 1
y0 = 2
z0 = 3
x[0] = x0
y[0] = y0
z[0] = z0
# computer the first 1000 elements of the sequences
for i in range(0,999):
  x_next = x[i] + roh*(y[i]-x[i])*dt
  y_next = y[i] + (x[i]*(r-z[i])-y[i])*dt
  z_next = z[i] + (x[i]*y[i]-b*z[i])*dt
  x[i+1] = x_next
  y[i+1] = y_next
  z[i+1] = z_next
#Plot the trajectory in 3D
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.gca(projection='3d')
ax.plot(x,y,z)
plt.show()

# Conclusions: b value affects the density of the circles both in the left side and right side
print("Conclusions: b value affects the density of the circles both in the left side and right side")
print("===============================================================================================")

print("How does r value affect the system?")
# case 1: 
roh = 10
b = 8/3
r = 20
x0 = 1
y0 = 2
z0 = 3
x[0] = x0
y[0] = y0
z[0] = z0
# computer the first 1000 elements of the sequences
for i in range(0,999):
  x_next = x[i] + roh*(y[i]-x[i])*dt
  y_next = y[i] + (x[i]*(r-z[i])-y[i])*dt
  z_next = z[i] + (x[i]*y[i]-b*z[i])*dt
  x[i+1] = x_next
  y[i+1] = y_next
  z[i+1] = z_next
#Plot the trajectory in 3D
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.gca(projection='3d')
ax.plot(x,y,z)
plt.show()

# case 2: 
roh = 10
b = 8/3
r = 15
x0 = 1
y0 = 2
z0 = 3
x[0] = x0
y[0] = y0
z[0] = z0
# computer the first 1000 elements of the sequences
for i in range(0,999):
  x_next = x[i] + roh*(y[i]-x[i])*dt
  y_next = y[i] + (x[i]*(r-z[i])-y[i])*dt
  z_next = z[i] + (x[i]*y[i]-b*z[i])*dt
  x[i+1] = x_next
  y[i+1] = y_next
  z[i+1] = z_next
#Plot the trajectory in 3D
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.gca(projection='3d')
ax.plot(x,y,z)
plt.show()

# case 3: 
roh = 10
b = 8/3
r = 10
x0 = 1
y0 = 2
z0 = 3
x[0] = x0
y[0] = y0
z[0] = z0
# computer the first 1000 elements of the sequences
for i in range(0,999):
  x_next = x[i] + roh*(y[i]-x[i])*dt
  y_next = y[i] + (x[i]*(r-z[i])-y[i])*dt
  z_next = z[i] + (x[i]*y[i]-b*z[i])*dt
  x[i+1] = x_next
  y[i+1] = y_next
  z[i+1] = z_next
#Plot the trajectory in 3D
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.gca(projection='3d')
ax.plot(x,y,z)
plt.show()

# case 4: 
roh = 10
b = 8/3
r = 5
x0 = 1
y0 = 2
z0 = 3
x[0] = x0
y[0] = y0
z[0] = z0
# computer the first 1000 elements of the sequences
for i in range(0,999):
  x_next = x[i] + roh*(y[i]-x[i])*dt
  y_next = y[i] + (x[i]*(r-z[i])-y[i])*dt
  z_next = z[i] + (x[i]*y[i]-b*z[i])*dt
  x[i+1] = x_next
  y[i+1] = y_next
  z[i+1] = z_next
#Plot the trajectory in 3D
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.gca(projection='3d')
ax.plot(x,y,z)
plt.show()

# case 5: 
roh = 10
b = 8/3
r = 34
x0 = 1
y0 = 2
z0 = 3
x[0] = x0
y[0] = y0
z[0] = z0
# computer the first 1000 elements of the sequences
for i in range(0,999):
  x_next = x[i] + roh*(y[i]-x[i])*dt
  y_next = y[i] + (x[i]*(r-z[i])-y[i])*dt
  z_next = z[i] + (x[i]*y[i]-b*z[i])*dt
  x[i+1] = x_next
  y[i+1] = y_next
  z[i+1] = z_next
#Plot the trajectory in 3D
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.gca(projection='3d')
ax.plot(x,y,z)
plt.show()

# Conclusions: r value affects the size of the circles both in the left side and right side
print("Conclusions: r value affects the size of the circles both in the left side and right side")
# Out:
# The probabilities T for transmission:
# 0.7301261363877617
# The probabilities R for reflection:
# 0.26987386361223836
# ...
# computer the first 1000 elements of the sequences:
# ...
